# %%
import pandas as pd
import numpy as np

import jieba
import jieba.posseg as pseg
import jieba.analyse

import sys
from optparse import OptionParser
import pprint
from prettytable import PrettyTable

# %%
df = pd.read_csv(open('../data/df_small.csv'))
df = df[df['text'].str.contains("https|Britain")== False]
print('有{}筆對話'.format(len(df)))
# Out:
# 有91340筆對話

# %% [markdown]
# ## groupby

# %%
grouped_data = df.groupby('from')['text'].apply(lambda x: '/'.join(x)).reset_index()
l = len(grouped_data)
print('有{}個使用者'.format(l))
# Out:
# 有1019個使用者

# %% [markdown]
# ## 先用前1000筆資料做測試

# %%
test = grouped_data.head(1000)
test_len = len(test)
test.head()
# Out:
#                from                                               text
# 0  1000970273334199  找不到阿/安安/你有打LOL嗎/好吧，可以帶我嗎/安安/凸/Sor/嗯/約哪/有啊/你先約的...
# 1  1001070263323689  !?/唐寶寶/你那麼愛慕他ㄇ/嗨/先問問您期望本人的性別是?/了解/我是男的/抱歉沒有/請問...
# 2  1001967239901904  早/在床上發懶/爆/斷/魂/你在暗諷綠藻嘛/壞/話說我好餓ㄛ/窩不要這個qq/ㄋ早餐吃什麼/...
# 3  1003172849781848  甲/你要做我的0？/人生勝利組是不會來玩這個的/你一定不是c銘/也不是業王/葉你妹/被盜/其...
# 4  1003929993039131  吃噓/肥宅早/我們不是場外人/場外ㄈㄓ/我沒用了/安安/是喔/場外ㄈㄓ嗎/豪/斷/欸/在打手...

# %%
for i in range(len(test)):
    test.iloc[i][1] = test.iloc[i][1].split('/')
test.head()
# Out:
#                from                                               text
# 0  1000970273334199  [找不到阿, 安安, 你有打LOL嗎, 好吧，可以帶我嗎, 安安, 凸, Sor, 嗯, 約...
# 1  1001070263323689  [!?, 唐寶寶, 你那麼愛慕他ㄇ, 嗨, 先問問您期望本人的性別是?, 了解, 我是男的,...
# 2  1001967239901904  [早, 在床上發懶, 爆, 斷, 魂, 你在暗諷綠藻嘛, 壞, 話說我好餓ㄛ, 窩不要這個q...
# 3  1003172849781848  [甲, 你要做我的0？, 人生勝利組是不會來玩這個的, 你一定不是c銘, 也不是業王, 葉你...
# 4  1003929993039131  [吃噓, 肥宅早, 我們不是場外人, 場外ㄈㄓ, 我沒用了, 安安, 是喔, 場外ㄈㄓ嗎, ...

# %%
print('id為 {} 的使用者傳送的訊息{}'.format(test.iloc[0][0],test.iloc[0][1]))
# Out:
# id為 1000970273334199 的使用者傳送的訊息['找不到阿', '安安', '你有打LOL嗎', '好吧，可以帶我嗎', '安安', '凸', 'Sor', '嗯', '約哪', '有啊', '你先約的啊', '喔', '輸入0088', '我懶的打了', '皮米屌', '這你嗎？', '魏癢癢', '哪裡人?', '住哪裡啦？', '超癢', '哪裡人?', '好遠', '其實還好', '新竹', '龍潭?', 'ㄏㄅㄨㄐㄅㄌㄗㄋ', '三小', '幹又ㄋ', '掰掰', '凹?', '凸sor']

# %%
jieba.set_dictionary('jieba_txt/dict.txt.big.txt')
stopwordset = set()
with open('jieba_txt/stop_words.txt','r',encoding='utf-8') as sw:
    for line in sw:
        stopwordset.add(line.strip('\n'))
stopwordset
# Out:
# {'10',
#  '20',
#  '2016',
#  '?',
#  '他',
#  '他們',
#  '你',
#  '台灣',
#  '她',
#  '對於',
#  '成為',
#  '我',
#  '我們',
#  '沒有',
#  '王隆甫',
#  '？'}

# %%
chars = set(' abcdefghijklmnopqrstuvwxyz0123456789()?!$,:.。，-_&=/􀆿\r\n')
for c in chars:
    stopwordset.add(c)

# %%
# stopwordset

# %% [markdown]
# ## gensim model

# %%
from gensim import models
import gensim

# %%
sentences = models.word2vec.LineSentence("corpusSegDone.txt")
model = models.word2vec.Word2Vec(sentences, size=1, window=5, min_count=5, workers=1)
model.wv.vocab
# Out:
# {'白痴': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a92e8>,
#  '腐女': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d160>,
#  '那時候': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3828>,
#  '誌': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530cc0>,
#  '讓': <gensim.models.keyedvectors.Vocab at 0x7f6dd85decf8>,
#  '爛': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1cf8>,
#  'Xd': <gensim.models.keyedvectors.Vocab at 0x7f6dd85515c0>,
#  '永遠': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d1d0>,
#  '進': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587550>,
#  '南': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a2358>,
#  '刷': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574668>,
#  '揍': <gensim.models.keyedvectors.Vocab at 0x7f6dd882cc50>,
#  '葉王': <gensim.models.keyedvectors.Vocab at 0x7f6dd85430f0>,
#  '吉娃娃': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a9550>,
#  '改名': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c36a0>,
#  '承認': <gensim.models.keyedvectors.Vocab at 0x7f6dd85948d0>,
#  '版主': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c35f8>,
#  '躺': <gensim.models.keyedvectors.Vocab at 0x7f6dd85746d8>,
#  'q': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587588>,
#  '設定': <gensim.models.keyedvectors.Vocab at 0x7f6dd85875c0>,
#  '吵架': <gensim.models.keyedvectors.Vocab at 0x7f6dd85875f8>,
#  '存錢': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3710>,
#  '自言': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3748>,
#  '隨機配': <gensim.models.keyedvectors.Vocab at 0x7f6dd85ded68>,
#  '結束': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574748>,
#  'I8': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530d30>,
#  '同一': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587668>,
#  '很無聊': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3780>,
#  '退出': <gensim.models.keyedvectors.Vocab at 0x7f6dd8540940>,
#  '意外': <gensim.models.keyedvectors.Vocab at 0x7f6dd85749b0>,
#  '娘': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574a20>,
#  '高一': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574a90>,
#  '〓': <gensim.models.keyedvectors.Vocab at 0x7f6dd85876d8>,
#  '報': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574ba8>,
#  '開車': <gensim.models.keyedvectors.Vocab at 0x7f6dd85deda0>,
#  '另': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3ac8>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a8470>,
#  '百貨': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1da0>,
#  '硬硬': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d278>,
#  '系學會': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587780>,
#  '熟': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c37b8>,
#  '騎': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574da0>,
#  '126362190881911': <gensim.models.keyedvectors.Vocab at 0x7f6dd8546c18>,
#  '似的': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a320>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x7f6dd85dedd8>,
#  '1031300387': <gensim.models.keyedvectors.Vocab at 0x7f6dd85dee10>,
#  '鴨': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d2b0>,
#  '遺憾': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a8080>,
#  '儘': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c37f0>,
#  '吉': <gensim.models.keyedvectors.Vocab at 0x7f6dd85877b8>,
#  '😥': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c32e8>,
#  '摳': <gensim.models.keyedvectors.Vocab at 0x7f6dd858aef0>,
#  'ts': <gensim.models.keyedvectors.Vocab at 0x7f6dd85dee48>,
#  '°': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d2e8>,
#  '休學': <gensim.models.keyedvectors.Vocab at 0x7f6dd85779b0>,
#  '動漫': <gensim.models.keyedvectors.Vocab at 0x7f6dd882cda0>,
#  '系統': <gensim.models.keyedvectors.Vocab at 0x7f6dd8544550>,
#  '浪費': <gensim.models.keyedvectors.Vocab at 0x7f6dd85747b8>,
#  '放下': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530dd8>,
#  '男女': <gensim.models.keyedvectors.Vocab at 0x7f6dd85deeb8>,
#  '懶得': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d358>,
#  '給點': <gensim.models.keyedvectors.Vocab at 0x7f6dd85deef0>,
#  '考試': <gensim.models.keyedvectors.Vocab at 0x7f6dd85747f0>,
#  '當時': <gensim.models.keyedvectors.Vocab at 0x7f6dd85def28>,
#  '企業': <gensim.models.keyedvectors.Vocab at 0x7f6dd85def60>,
#  '0078': <gensim.models.keyedvectors.Vocab at 0x7f6dd8537d30>,
#  '那個': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dd30>,
#  '不來': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d3c8>,
#  '叮噹': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530e48>,
#  '其': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ce48>,
#  '162929011': <gensim.models.keyedvectors.Vocab at 0x7f6dd857cd30>,
#  '被鎖': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a67f0>,
#  '度': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1eb8>,
#  'า': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d400>,
#  '明天': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3470>,
#  '影片': <gensim.models.keyedvectors.Vocab at 0x7f6dd853dda0>,
#  '一點': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1ef0>,
#  '一小': <gensim.models.keyedvectors.Vocab at 0x7f6dd85746a0>,
#  '出門': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530eb8>,
#  '57C12BD8': <gensim.models.keyedvectors.Vocab at 0x7f6dd852ac18>,
#  '_': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f048>,
#  '⊱': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f080>,
#  '臭甲': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c35c0>,
#  'png': <gensim.models.keyedvectors.Vocab at 0x7f6dd88650b8>,
#  '喵': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530ef0>,
#  '◟': <gensim.models.keyedvectors.Vocab at 0x7f6dd852af60>,
#  '只會': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587860>,
#  '先講': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d438>,
#  '肛': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530f28>,
#  '國中生': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577470>,
#  '瞭解': <gensim.models.keyedvectors.Vocab at 0x7f6dd85def98>,
#  '洗': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530f60>,
#  '頭': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c34a8>,
#  '有加': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3358>,
#  '婊': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d470>,
#  '∇': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ad30>,
#  '加班': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ce80>,
#  '帥哥': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ceb8>,
#  '我心': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d1320>,
#  '台南人': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3588>,
#  '好不好': <gensim.models.keyedvectors.Vocab at 0x7f6dd85defd0>,
#  '拖': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1048>,
#  '野': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1080>,
#  '呆': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a9f28>,
#  '幾年': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535588>,
#  'b6ab833f4622f82ebcbfe4260d52210a': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f588>,
#  '\U00100503': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3668>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3390>,
#  '訂': <gensim.models.keyedvectors.Vocab at 0x7f6dd882cf28>,
#  '๑': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e10b8>,
#  '打給': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d4e0>,
#  '理想': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf668>,
#  '操': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d518>,
#  '會不會': <gensim.models.keyedvectors.Vocab at 0x7f6dd85878d0>,
#  '蝦': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587908>,
#  '綁': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a9780>,
#  '底': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3320>,
#  '短': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1f98>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x7f6dd882cf98>,
#  '成功': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e9e48>,
#  '問': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587940>,
#  '說人話': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577978>,
#  '改天': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3630>,
#  '午安': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e10f0>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f860>,
#  'Z': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548da0>,
#  '沒電腦': <gensim.models.keyedvectors.Vocab at 0x7f6dd85320f0>,
#  '理解': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c33c8>,
#  '口交': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587978>,
#  '我肥宅': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574710>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f6dd8546ba8>,
#  '你場': <gensim.models.keyedvectors.Vocab at 0x7f6dd8544588>,
#  '螳螂': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587630>,
#  '出來': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d550>,
#  '14080902': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf908>,
#  '14159030': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574860>,
#  '成熟': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3860>,
#  'yee': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865278>,
#  '粉團': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a8cf8>,
#  '葉': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1198>,
#  '9453': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e11d0>,
#  '通常': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865400>,
#  '斷': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574898>,
#  '沒聊過': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577c88>,
#  'bug': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532128>,
#  '8.7': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1208>,
#  '兒': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3898>,
#  '原本': <gensim.models.keyedvectors.Vocab at 0x7f6dd85879b0>,
#  '這才': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1278>,
#  '烤肉': <gensim.models.keyedvectors.Vocab at 0x7f6dd85748d0>,
#  '玩遊戲': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543a90>,
#  '約過': <gensim.models.keyedvectors.Vocab at 0x7f6dd882cfd0>,
#  '月底': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c38d0>,
#  '｡': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574908>,
#  '隻': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541048>,
#  '好歐': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e12e8>,
#  '়': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d5c0>,
#  '篇': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1320>,
#  '首先': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532160>,
#  '課': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532198>,
#  '勝利': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587a20>,
#  '輸': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577e48>,
#  '嘻嘻': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d668>,
#  'oe': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d6a0>,
#  '港覺': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574940>,
#  '走開': <gensim.models.keyedvectors.Vocab at 0x7f6dd853a7f0>,
#  '謊': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574978>,
#  '生氣': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548e80>,
#  '外群': <gensim.models.keyedvectors.Vocab at 0x7f6dd85321d0>,
#  '第二': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865860>,
#  '講是': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587a58>,
#  '🙈': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587a90>,
#  '肥': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532208>,
#  '還是': <gensim.models.keyedvectors.Vocab at 0x7f6dd85410f0>,
#  'ㄑ': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587ac8>,
#  '一開始': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a5b00>,
#  '有些': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d1e80>,
#  '你長': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541128>,
#  'Japan': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3940>,
#  '我弟': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a2e48>,
#  '香蕉': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587b38>,
#  '連到': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a0b8>,
#  '賠': <gensim.models.keyedvectors.Vocab at 0x7f6dd85749e8>,
#  '泡': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ccc0>,
#  '不爽': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f668>,
#  '花': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587ba8>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574a58>,
#  '弱': <gensim.models.keyedvectors.Vocab at 0x7f6dd85876a0>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574ac8>,
#  '怎辦': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587be0>,
#  '1240809725950457': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587c18>,
#  '很爛': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ccf8>,
#  '14111699': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d748>,
#  '明明': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d8400>,
#  'チ': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574b00>,
#  '多大': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532278>,
#  '妹': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a0f0>,
#  '記者': <gensim.models.keyedvectors.Vocab at 0x7f6dd8579c50>,
#  '怪': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574b38>,
#  '年齡': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1358>,
#  '生': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a128>,
#  '\U00100195': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1dd8>,
#  '打炮': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c39b0>,
#  '▽': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1fd0>,
#  '對話': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c39e8>,
#  '運動': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1390>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574b70>,
#  '≦': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587c50>,
#  '女友': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e13c8>,
#  '甩': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1400>,
#  '陣亡': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e6b70>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x7f6dd85322b0>,
#  '發者': <gensim.models.keyedvectors.Vocab at 0x7f6dd85322e8>,
#  '愛心': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532320>,
#  '這次': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587c88>,
#  '我家': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1438>,
#  '圖書館': <gensim.models.keyedvectors.Vocab at 0x7f6dd8551550>,
#  '同': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3a58>,
#  'Ｙ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a2908>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f6dd85323c8>,
#  '皮卡': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3a90>,
#  '知道': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d240>,
#  '哭哭': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b5c0>,
#  'messenger': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a5cf8>,
#  '感受': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3b00>,
#  '我頭': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541208>,
#  '看場': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541240>,
#  '然後很氣': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1470>,
#  '雞排': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a160>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x7f6dd85486a0>,
#  '經驗': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532438>,
#  '還說': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1518>,
#  '12504175': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587cf8>,
#  '告訴': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a198>,
#  '認': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1550>,
#  '我葉王': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a2d30>,
#  '誤會': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fe80>,
#  '老公': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541278>,
#  '去年': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f6d8>,
#  '睡不著': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3b38>,
#  '國民': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf6a0>,
#  '隨便': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543748>,
#  '還騙': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1588>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x7f6dd85412b0>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b438>,
#  '妳是': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f710>,
#  '落葉': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587d30>,
#  '墮': <gensim.models.keyedvectors.Vocab at 0x7f6dd85442e8>,
#  '呵呵': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a9668>,
#  'Lol': <gensim.models.keyedvectors.Vocab at 0x7f6dd85412e8>,
#  '一歲': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3b70>,
#  '17sing': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574c18>,
#  '恨': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587d68>,
#  '愛情': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1e10>,
#  '녕': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3ba8>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d860>,
#  '大哥': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541320>,
#  '掉': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e15c0>,
#  '超帥': <gensim.models.keyedvectors.Vocab at 0x7f6dd85324a8>,
#  '誰': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587da0>,
#  '三年': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a41d0>,
#  'imgur': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a4208>,
#  'ㄋ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a4240>,
#  'Д': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574c50>,
#  '干': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e15f8>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1630>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d8d0>,
#  'ﾟ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a42e8>,
#  '宅': <gensim.models.keyedvectors.Vocab at 0x7f6dd854be48>,
#  '下個': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a2b0>,
#  '值得': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574c88>,
#  '━': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1160>,
#  '光頭': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d908>,
#  '好大': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587e10>,
#  '一口': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532550>,
#  '肉': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574cc0>,
#  '另外': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574cf8>,
#  '發': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3c50>,
#  '樂觀': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574d30>,
#  't35.0': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532588>,
#  '出現': <gensim.models.keyedvectors.Vocab at 0x7f6dd8546ef0>,
#  '託': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1668>,
#  '間': <gensim.models.keyedvectors.Vocab at 0x7f6dd8579cf8>,
#  '8787': <gensim.models.keyedvectors.Vocab at 0x7f6dd85325c0>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x7f6dd853abe0>,
#  '同校': <gensim.models.keyedvectors.Vocab at 0x7f6dd853def0>,
#  '1600': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d940>,
#  '籤': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d978>,
#  '風格': <gensim.models.keyedvectors.Vocab at 0x7f6dd85325f8>,
#  '處女': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d9b0>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3c88>,
#  '看電影': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587e80>,
#  '普普': <gensim.models.keyedvectors.Vocab at 0x7f6dd8537828>,
#  '電學': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541400>,
#  '澎湖': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3cc0>,
#  '近來': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532630>,
#  '真心': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d9e8>,
#  '還記': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587eb8>,
#  '顯示': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a7518>,
#  'cda28ecb8387442994f4c735febd295a': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3d30>,
#  '笑': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574dd8>,
#  '狂': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541438>,
#  '麥當勞': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532668>,
#  'icu': <gensim.models.keyedvectors.Vocab at 0x7f6dd85326a0>,
#  '觘': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e16a0>,
#  '錯頻': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587ef0>,
#  '嘉義': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574e10>,
#  '超可愛': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e16d8>,
#  '若': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1908>,
#  '我本來': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a358>,
#  '靜靜': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a390>,
#  '回覆': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1710>,
#  'fb': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574e48>,
#  '還在': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532ef0>,
#  '稀奇': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1748>,
#  '舔': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1780>,
#  '太少': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541b00>,
#  '~': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574e80>,
#  '耐心': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574eb8>,
#  '.......': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f588>,
#  '霸主': <gensim.models.keyedvectors.Vocab at 0x7f6dd882c9e8>,
#  '闆': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587f28>,
#  '快': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a3c8>,
#  '教育': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e17b8>,
#  '80': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4630>,
#  '六': <gensim.models.keyedvectors.Vocab at 0x7f6dd859da20>,
#  '我私': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3da0>,
#  '溫暖': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e17f0>,
#  '散戶': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865a90>,
#  '18m': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535518>,
#  'chara': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1828>,
#  '綠': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587f98>,
#  '鯉魚': <gensim.models.keyedvectors.Vocab at 0x7f6dd857c5f8>,
#  '找別': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a4e48>,
#  't34.0': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1a20>,
#  '好奇': <gensim.models.keyedvectors.Vocab at 0x7f6dd85411d0>,
#  '曬': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3c18>,
#  '半小時': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1860>,
#  'yo': <gensim.models.keyedvectors.Vocab at 0x7f6dd857c748>,
#  '近': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530d68>,
#  'ろ': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541588>,
#  '十秒': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587fd0>,
#  'H': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a86a0>,
#  '肛肛': <gensim.models.keyedvectors.Vocab at 0x7f6dd85415c0>,
#  '東西': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a470>,
#  '😰': <gensim.models.keyedvectors.Vocab at 0x7f6dd859db00>,
#  'ภ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3dd8>,
#  '板': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1898>,
#  '真假': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a048>,
#  '5000': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e18d0>,
#  '實話': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574f60>,
#  '98': <gensim.models.keyedvectors.Vocab at 0x7f6dd859db38>,
#  '超愛': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3e10>,
#  'z': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3e48>,
#  '藝術': <gensim.models.keyedvectors.Vocab at 0x7f6dd8594a90>,
#  '當兵': <gensim.models.keyedvectors.Vocab at 0x7f6dd85415f8>,
#  'wqd': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574f98>,
#  '耶': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a4e0>,
#  '哎': <gensim.models.keyedvectors.Vocab at 0x7f6dd857ca58>,
#  '✨': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1908>,
#  '猜': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1940>,
#  '＝': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577048>,
#  '저': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541630>,
#  '💩': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a518>,
#  '娟': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3e80>,
#  '星姐': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a550>,
#  '緊張': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a7400>,
#  '台中人': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532780>,
#  '孤兒': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543828>,
#  '屁話': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548e48>,
#  '順便': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1978>,
#  '路': <gensim.models.keyedvectors.Vocab at 0x7f6dd85327b8>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x7f6dd859db70>,
#  '高校': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577080>,
#  '紀錄': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3eb8>,
#  '後': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3ef0>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532b70>,
#  '安安': <gensim.models.keyedvectors.Vocab at 0x7f6dd85810f0>,
#  '踹': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e19b0>,
#  '那麼': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532828>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7f6dd85db940>,
#  '一邊': <gensim.models.keyedvectors.Vocab at 0x7f6dd85770b8>,
#  '數': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a588>,
#  'Why': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dba8>,
#  '黯': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dbe0>,
#  'ç': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e19e8>,
#  '宜蘭人': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532898>,
#  'Ѽ': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a5208>,
#  '信心': <gensim.models.keyedvectors.Vocab at 0x7f6ddba68eb8>,
#  '類似': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541780>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a7748>,
#  '87': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1a20>,
#  '封面': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a5f8>,
#  '無感': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a0f0>,
#  '國外': <gensim.models.keyedvectors.Vocab at 0x7f6dd85328d0>,
#  '³': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a128>,
#  '腕力': <gensim.models.keyedvectors.Vocab at 0x7f6dd857e0f0>,
#  'Gan': <gensim.models.keyedvectors.Vocab at 0x7f6dd85374a8>,
#  '爆氣': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a630>,
#  '打個': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a160>,
#  'に': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532908>,
#  '照片': <gensim.models.keyedvectors.Vocab at 0x7f6dd85770f0>,
#  '老': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577128>,
#  '公威': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1a90>,
#  '我現': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541828>,
#  '哪間': <gensim.models.keyedvectors.Vocab at 0x7f6dd854bcf8>,
#  '煩': <gensim.models.keyedvectors.Vocab at 0x7f6dd857e198>,
#  '問我': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dc18>,
#  '特別': <gensim.models.keyedvectors.Vocab at 0x7f6dd85db9b0>,
#  '完': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b3c8>,
#  '傷害': <gensim.models.keyedvectors.Vocab at 0x7f6dd853ac18>,
#  '\uf002': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532940>,
#  'XD': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a69b0>,
#  '矮': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a6a0>,
#  '褲襪': <gensim.models.keyedvectors.Vocab at 0x7f6dd85355c0>,
#  '便宜': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a75f8>,
#  '口味': <gensim.models.keyedvectors.Vocab at 0x7f6dd85329b0>,
#  '之前': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a7ac8>,
#  'ƪ': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a5160>,
#  '誠實點': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3f60>,
#  '勒': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a710>,
#  '模式': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577160>,
#  '小妹妹': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dc50>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7f6dd8544e10>,
#  '福利': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1b00>,
#  'Р': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f7b8>,
#  '一顆': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1748>,
#  'PO': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d390>,
#  '科': <gensim.models.keyedvectors.Vocab at 0x7f6ddba81710>,
#  '果然': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577198>,
#  '她': <gensim.models.keyedvectors.Vocab at 0x7f6dd85771d0>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3f98>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f6dd85c3fd0>,
#  '٩': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a780>,
#  '不少': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dcc0>,
#  '給窩': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dcf8>,
#  '스': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ce10>,
#  '床上': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a208>,
#  '歌': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f860>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf048>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a66a0>,
#  '專': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541898>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a7b8>,
#  '啞巴': <gensim.models.keyedvectors.Vocab at 0x7f6dd853d908>,
#  '劇透': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b748>,
#  '女性': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a7f0>,
#  '哩': <gensim.models.keyedvectors.Vocab at 0x7f6dd856ef98>,
#  '本名': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a828>,
#  '他媽': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf080>,
#  '一波': <gensim.models.keyedvectors.Vocab at 0x7f6dd857ceb8>,
#  '新聞': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a240>,
#  '塞': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a278>,
#  '談戀': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf0b8>,
#  '梅亭': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d6c18>,
#  '棒呆': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf0f0>,
#  '屎': <gensim.models.keyedvectors.Vocab at 0x7f6dd85400b8>,
#  '愛嗎': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532ac8>,
#  '聊天室': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dd68>,
#  '台': <gensim.models.keyedvectors.Vocab at 0x7f6dd859dda0>,
#  '理': <gensim.models.keyedvectors.Vocab at 0x7f6dd8537908>,
#  'ㄎ': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a96d8>,
#  '謎': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d6da0>,
#  '太難': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1ba8>,
#  '巴哈姆': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d6e10>,
#  '驕傲': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a898>,
#  '%%': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577208>,
#  '中部': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532b38>,
#  '找': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a8d0>,
#  '我讀': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1be0>,
#  '87%': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1c18>,
#  '貨都': <gensim.models.keyedvectors.Vocab at 0x7f6dd859de10>,
#  '天天': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b518>,
#  '複': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a320>,
#  '喜歡': <gensim.models.keyedvectors.Vocab at 0x7f6dd85917b8>,
#  '訊息': <gensim.models.keyedvectors.Vocab at 0x7f6dd857eac8>,
#  '沒事': <gensim.models.keyedvectors.Vocab at 0x7f6dd8544748>,
#  '丸': <gensim.models.keyedvectors.Vocab at 0x7f6dd857eb38>,
#  '支援': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf160>,
#  'Laughter': <gensim.models.keyedvectors.Vocab at 0x7f6dd85915c0>,
#  '通知': <gensim.models.keyedvectors.Vocab at 0x7f6dd859de48>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532ba8>,
#  '結婚': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1c88>,
#  '做什麼': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1cc0>,
#  '笑笑': <gensim.models.keyedvectors.Vocab at 0x7f6dd859de80>,
#  '牽手': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a3c8>,
#  '小屁孩': <gensim.models.keyedvectors.Vocab at 0x7f6dd85419b0>,
#  '插下去': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532be0>,
#  '穴穴': <gensim.models.keyedvectors.Vocab at 0x7f6dd859deb8>,
#  '抽': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577240>,
#  '健康': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577278>,
#  '哪科': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a6eb8>,
#  '結果': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1d30>,
#  '低調': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532c18>,
#  '訓練': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a908>,
#  '文章': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532c50>,
#  '威': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a5048>,
#  '成': <gensim.models.keyedvectors.Vocab at 0x7f6dd85419e8>,
#  '╯': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541a20>,
#  '大家': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fa20>,
#  '沒加': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a438>,
#  '太遠': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532358>,
#  'й': <gensim.models.keyedvectors.Vocab at 0x7f6dd859def0>,
#  '錄': <gensim.models.keyedvectors.Vocab at 0x7f6dd882a940>,
#  '喜翻': <gensim.models.keyedvectors.Vocab at 0x7f6dd85772b0>,
#  '我甲甲': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541a58>,
#  '254357215': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f898>,
#  '歉': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541a90>,
#  '你加': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587828>,
#  'Ӧ': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a4a8>,
#  '幹掛網': <gensim.models.keyedvectors.Vocab at 0x7f6dd859df28>,
#  '電腦版': <gensim.models.keyedvectors.Vocab at 0x7f6dd853ac88>,
#  '正妹': <gensim.models.keyedvectors.Vocab at 0x7f6dd85772e8>,
#  'ਸ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d8518>,
#  '愛麗': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577320>,
#  '反串': <gensim.models.keyedvectors.Vocab at 0x7f6dd859df60>,
#  '1901476199': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a4e0>,
#  '57C0DA58': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532cc0>,
#  '先傳': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541ac8>,
#  '腳': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532cf8>,
#  '誤': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1d68>,
#  '嘴炮': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1da0>,
#  '数学': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d8668>,
#  '廢話': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548080>,
#  'ㄟ': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532d30>,
#  '決定': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532d68>,
#  '欺騙': <gensim.models.keyedvectors.Vocab at 0x7f6dd85300f0>,
#  '休幹': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf198>,
#  '生活': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1dd8>,
#  '名來': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1e10>,
#  '6666': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d1f60>,
#  '欠': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1e48>,
#  '851587': <gensim.models.keyedvectors.Vocab at 0x7f6dd85517b8>,
#  '蠔': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541b70>,
#  '💕': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a518>,
#  '愛愛': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1e80>,
#  '00': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532da0>,
#  '汁妹': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf208>,
#  '慢': <gensim.models.keyedvectors.Vocab at 0x7f6dd882aa58>,
#  '拍': <gensim.models.keyedvectors.Vocab at 0x7f6dd8551438>,
#  '算還': <gensim.models.keyedvectors.Vocab at 0x7f6dd8574828>,
#  '中壢佳': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f8d0>,
#  '給虧': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f0b8>,
#  '差別': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532e10>,
#  '關心': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f0f0>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532e48>,
#  '更新': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f128>,
#  '我想': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1eb8>,
#  '回話': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532e80>,
#  '周杰倫': <gensim.models.keyedvectors.Vocab at 0x7f6dd85710f0>,
#  'gamer': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ab00>,
#  '八卦': <gensim.models.keyedvectors.Vocab at 0x7f6dd8581940>,
#  'ppt': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541c88>,
#  '這張': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541e10>,
#  '有興趣': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577390>,
#  'ㄝ': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f198>,
#  '腿照': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a5b70>,
#  '然後我': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548f98>,
#  '還我': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ab38>,
#  '外勞': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f940>,
#  '1125082285': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f1d0>,
#  '累': <gensim.models.keyedvectors.Vocab at 0x7f6dd85773c8>,
#  '一間': <gensim.models.keyedvectors.Vocab at 0x7f6dd85742e8>,
#  '*': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532eb8>,
#  '髒': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f240>,
#  '聽起': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f278>,
#  '大二': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541cc0>,
#  '工具': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf278>,
#  '私立': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541cf8>,
#  'ば': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ac18>,
#  '不用': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577438>,
#  '淦': <gensim.models.keyedvectors.Vocab at 0x7f6dd85489b0>,
#  '一班': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf2b0>,
#  '愛莉絲': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf2e8>,
#  'Hello': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a550>,
#  '霸社': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f2b0>,
#  '駕': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf320>,
#  '員': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548c18>,
#  '睡著': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f2e8>,
#  '喔': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587898>,
#  '番': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ac50>,
#  '交個': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1f98>,
#  '面': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ac88>,
#  '花蓮': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f320>,
#  '想要': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541da0>,
#  '唬': <gensim.models.keyedvectors.Vocab at 0x7f6dd882acc0>,
#  '吉他': <gensim.models.keyedvectors.Vocab at 0x7f6dd85774a8>,
#  '摸': <gensim.models.keyedvectors.Vocab at 0x7f6dd85db278>,
#  '生命': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf390>,
#  '愛我': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541978>,
#  '年輕': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f390>,
#  '剛被': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1fd0>,
#  '油': <gensim.models.keyedvectors.Vocab at 0x7f6dd85774e0>,
#  '尊重': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a588>,
#  '推': <gensim.models.keyedvectors.Vocab at 0x7f6dd852a978>,
#  '打電話': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530f98>,
#  '硬': <gensim.models.keyedvectors.Vocab at 0x7f6dd854f978>,
#  '自拍照': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf3c8>,
#  '͞': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c198>,
#  'る': <gensim.models.keyedvectors.Vocab at 0x7f6dd8551390>,
#  '超過': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4080>,
#  '跳樓': <gensim.models.keyedvectors.Vocab at 0x7f6dd8540b70>,
#  '147': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a5f8>,
#  '遇過': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a630>,
#  '齁': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b630>,
#  '溝通': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a668>,
#  '七七': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e40f0>,
#  '¿': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541dd8>,
#  '歡迎': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532f98>,
#  'з': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530e10>,
#  '😓': <gensim.models.keyedvectors.Vocab at 0x7f6dd8579b38>,
#  '剛跟': <gensim.models.keyedvectors.Vocab at 0x7f6dd882ad68>,
#  '看得懂': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a6a0>,
#  '吾': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf400>,
#  '0808': <gensim.models.keyedvectors.Vocab at 0x7f6dd85db6d8>,
#  '人用': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf438>,
#  '男校': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f400>,
#  '💓': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535048>,
#  '0.0': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f470>,
#  '感覺': <gensim.models.keyedvectors.Vocab at 0x7f6dd85843c8>,
#  '提早': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f4a8>,
#  '腦子': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4128>,
#  '傳圖片': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf470>,
#  '我錯': <gensim.models.keyedvectors.Vocab at 0x7f6dd8597908>,
#  '熊怪': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f4e0>,
#  '日記': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a97f0>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf4a8>,
#  '高職': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b4a8>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577550>,
#  'Yee': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535080>,
#  '鼻要': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4160>,
#  '疼': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf4e0>,
#  '唸': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f518>,
#  '輕': <gensim.models.keyedvectors.Vocab at 0x7f6dd852d9b0>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf518>,
#  '健檢': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535c50>,
#  '泥': <gensim.models.keyedvectors.Vocab at 0x7f6dd8571128>,
#  'XDD': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf550>,
#  '醜女': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4198>,
#  'More': <gensim.models.keyedvectors.Vocab at 0x7f6dd85dbba8>,
#  '할': <gensim.models.keyedvectors.Vocab at 0x7f6dd853d710>,
#  '太油': <gensim.models.keyedvectors.Vocab at 0x7f6dd8594c88>,
#  '內': <gensim.models.keyedvectors.Vocab at 0x7f6dd85775c0>,
#  '雲林': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e41d0>,
#  '社團裡': <gensim.models.keyedvectors.Vocab at 0x7f6dd85350f0>,
#  '哪種': <gensim.models.keyedvectors.Vocab at 0x7f6dd85775f8>,
#  '表情': <gensim.models.keyedvectors.Vocab at 0x7f6dd8584860>,
#  '484': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f550>,
#  '找到': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865470>,
#  '沒什麼': <gensim.models.keyedvectors.Vocab at 0x7f6dd8551908>,
#  'ㅋ': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535128>,
#  '剛用': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f5c0>,
#  '玩玩': <gensim.models.keyedvectors.Vocab at 0x7f6dd8584978>,
#  '真': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535160>,
#  'ㄡ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf5c0>,
#  '會懷孕': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf5f8>,
#  '南台': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541e48>,
#  '正在': <gensim.models.keyedvectors.Vocab at 0x7f6dd882cf60>,
#  '不是': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f5f8>,
#  '用賴': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535198>,
#  '實際': <gensim.models.keyedvectors.Vocab at 0x7f6dd858f160>,
#  '零': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f630>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf630>,
#  'audioclip': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4208>,
#  '的關': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a780>,
#  '開場': <gensim.models.keyedvectors.Vocab at 0x7f6dd853de80>,
#  '毛': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a3828>,
#  '不住': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a3518>,
#  '011': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577668>,
#  '這些': <gensim.models.keyedvectors.Vocab at 0x7f6dd85351d0>,
#  '噓': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535208>,
#  'ㄗ': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a5c0>,
#  '1237185252': <gensim.models.keyedvectors.Vocab at 0x7f6dd882af60>,
#  '好感': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a7f0>,
#  '81KkBM': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535240>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x7f6dd85776a0>,
#  '耍': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a828>,
#  '黑白': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541eb8>,
#  '心': <gensim.models.keyedvectors.Vocab at 0x7f6dd8544898>,
#  '業障': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a10f0>,
#  'ㄔ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4240>,
#  'ਗ': <gensim.models.keyedvectors.Vocab at 0x7f6dd85de470>,
#  '胞胎': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577710>,
#  '嚇死': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577748>,
#  '還很年': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535278>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f668>,
#  'f': <gensim.models.keyedvectors.Vocab at 0x7f6dd85de518>,
#  '哪位': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a7550>,
#  '一張': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4278>,
#  '障礙': <gensim.models.keyedvectors.Vocab at 0x7f6dd85352e8>,
#  '放棄': <gensim.models.keyedvectors.Vocab at 0x7f6dd85917f0>,
#  '我台': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e42b0>,
#  '團體': <gensim.models.keyedvectors.Vocab at 0x7f6dd8546898>,
#  '囧': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a8d0>,
#  '癡': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a72b0>,
#  '廢文': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4320>,
#  '石頭': <gensim.models.keyedvectors.Vocab at 0x7f6dd85de5f8>,
#  'D': <gensim.models.keyedvectors.Vocab at 0x7f6dd882af98>,
#  '五分': <gensim.models.keyedvectors.Vocab at 0x7f6dd85480f0>,
#  '被車': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a15f8>,
#  '最近': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a908>,
#  '狀態': <gensim.models.keyedvectors.Vocab at 0x7f6dd85777f0>,
#  '我配': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f6a0>,
#  '蘋果': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a940>,
#  '車禍': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541f98>,
#  '查': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b080>,
#  '🙏': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f6d8>,
#  '巴巴': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a978>,
#  '看不懂': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a76d8>,
#  '一屆': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1780>,
#  '額': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a9b0>,
#  '有密語': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577828>,
#  '談': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a9e8>,
#  't39.1997': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541fd0>,
#  '排': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535390>,
#  '不加': <gensim.models.keyedvectors.Vocab at 0x7f6dd854fa58>,
#  '이': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a3c88>,
#  '沒怕過': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577860>,
#  '啊災': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4390>,
#  '57C1E01A': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e6390>,
#  '一般': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543048>,
#  '死場': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e43c8>,
#  '窺': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543080>,
#  '學期': <gensim.models.keyedvectors.Vocab at 0x7f6dd8546e80>,
#  'ย': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865080>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f6dd85430b8>,
#  '外流': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577898>,
#  '中正': <gensim.models.keyedvectors.Vocab at 0x7f6dd85401d0>,
#  '奇怪': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a3358>,
#  '0008': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f748>,
#  '三小': <gensim.models.keyedvectors.Vocab at 0x7f6dd85873c8>,
#  '汽水': <gensim.models.keyedvectors.Vocab at 0x7f6dd85353c8>,
#  '爺爺': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4400>,
#  '半夜': <gensim.models.keyedvectors.Vocab at 0x7f6dd85778d0>,
#  '本來': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530c18>,
#  '🖕': <gensim.models.keyedvectors.Vocab at 0x7f6dd858aa20>,
#  '分身': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4438>,
#  '收到': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf6d8>,
#  '創世神': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535400>,
#  '太棒了': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4470>,
#  '28': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf710>,
#  '030': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543128>,
#  '寂寞': <gensim.models.keyedvectors.Vocab at 0x7f6dd882af28>,
#  '\U00100010': <gensim.models.keyedvectors.Vocab at 0x7f6dd85516d8>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577908>,
#  '交往': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577940>,
#  '一群': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf748>,
#  '太久': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532a58>,
#  '還比': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e44e0>,
#  '•': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4518>,
#  '008': <gensim.models.keyedvectors.Vocab at 0x7f6dd85779e8>,
#  '睡醒': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577a20>,
#  '\U0010001a': <gensim.models.keyedvectors.Vocab at 0x7f6dd858aac8>,
#  '建華': <gensim.models.keyedvectors.Vocab at 0x7f6dd882c780>,
#  '網址': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535438>,
#  '魔貫光': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d66d8>,
#  '場外': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f7f0>,
#  '絕對': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f828>,
#  '無聊來': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf780>,
#  '你給': <gensim.models.keyedvectors.Vocab at 0x7f6dd854b8d0>,
#  '\U00100079': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ab38>,
#  '作': <gensim.models.keyedvectors.Vocab at 0x7f6dd85d30f0>,
#  '☞': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ab70>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x7f6dd8594d68>,
#  '抽插': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4550>,
#  '下去': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535470>,
#  '認錯': <gensim.models.keyedvectors.Vocab at 0x7f6dd8587b70>,
#  '其中': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf7f0>,
#  '困難': <gensim.models.keyedvectors.Vocab at 0x7f6dd85354a8>,
#  '用到': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543358>,
#  '機車': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4588>,
#  '入': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f898>,
#  '傻傻的': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865d68>,
#  '慾': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e45c0>,
#  'ち': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543208>,
#  '一種': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f8d0>,
#  '那給': <gensim.models.keyedvectors.Vocab at 0x7f6dd858aba8>,
#  '認識': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543240>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577a58>,
#  '保護': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e45f8>,
#  '哈哈': <gensim.models.keyedvectors.Vocab at 0x7f6dd88650f0>,
#  '黑色': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577a90>,
#  '屌': <gensim.models.keyedvectors.Vocab at 0x7f6dd858f4a8>,
#  '貓': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f908>,
#  '想約': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577ac8>,
#  '包皮': <gensim.models.keyedvectors.Vocab at 0x7f6dd85431d0>,
#  '蹦蹦': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865128>,
#  'ไ': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865160>,
#  '好哇': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548198>,
#  '乾': <gensim.models.keyedvectors.Vocab at 0x7f6dd858abe0>,
#  '拍照': <gensim.models.keyedvectors.Vocab at 0x7f6dd858aa90>,
#  '軍團': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4668>,
#  '♥': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ac18>,
#  '艾莉絲': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ac50>,
#  '一定': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf860>,
#  '暑假': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535550>,
#  '話': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577b00>,
#  '下來': <gensim.models.keyedvectors.Vocab at 0x7f6dd8540208>,
#  '給我閉': <gensim.models.keyedvectors.Vocab at 0x7f6dd853ada0>,
#  '喇': <gensim.models.keyedvectors.Vocab at 0x7f6dd8541710>,
#  '些': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a0b8>,
#  '阿阿阿': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf898>,
#  '座': <gensim.models.keyedvectors.Vocab at 0x7f6dd85432e8>,
#  '超怕': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e1160>,
#  '面會': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf8d0>,
#  '別亂': <gensim.models.keyedvectors.Vocab at 0x7f6dd8532978>,
#  '不如': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f940>,
#  '《': <gensim.models.keyedvectors.Vocab at 0x7f6dd85355f8>,
#  '每個': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535630>,
#  '太多': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535668>,
#  '肯德基': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e46a0>,
#  '給認識': <gensim.models.keyedvectors.Vocab at 0x7f6dd85356a0>,
#  '點擊': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e46d8>,
#  '眼淚': <gensim.models.keyedvectors.Vocab at 0x7f6dd858a2b0>,
#  '方劍華': <gensim.models.keyedvectors.Vocab at 0x7f6dd853da20>,
#  '我來': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543390>,
#  '太醜': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1f60>,
#  '全家': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4710>,
#  '研究所': <gensim.models.keyedvectors.Vocab at 0x7f6dd85356d8>,
#  '已經': <gensim.models.keyedvectors.Vocab at 0x7f6dd8540240>,
#  '400': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ac88>,
#  '爽': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535710>,
#  '人妖': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf940>,
#  '之': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535748>,
#  '遇到': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf978>,
#  '14138342': <gensim.models.keyedvectors.Vocab at 0x7f6dd858f4e0>,
#  '列出': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf9b0>,
#  'Hey': <gensim.models.keyedvectors.Vocab at 0x7f6dd88652b0>,
#  '只想': <gensim.models.keyedvectors.Vocab at 0x7f6dd858acc0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535780>,
#  '醒': <gensim.models.keyedvectors.Vocab at 0x7f6dd85357b8>,
#  'APP': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4748>,
#  '做事': <gensim.models.keyedvectors.Vocab at 0x7f6dd858acf8>,
#  '珍惜': <gensim.models.keyedvectors.Vocab at 0x7f6dd8530e80>,
#  '學校': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865320>,
#  '冰': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577b70>,
#  '配': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543400>,
#  '700': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f978>,
#  '五專': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f9b0>,
#  'LOL': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f9e8>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a5438>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x7f6dd85350b8>,
#  '窮': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cf9e8>,
#  '語言': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfa20>,
#  '我給': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ad68>,
#  '用': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fa90>,
#  '兩年': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e12b0>,
#  '堵': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfa58>,
#  '還以': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a8c50>,
#  '安全': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfa90>,
#  '泥豪': <gensim.models.keyedvectors.Vocab at 0x7f6dd85358d0>,
#  '要問': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfac8>,
#  '今晚': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e62b0>,
#  '糟糕': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ada0>,
#  '亂': <gensim.models.keyedvectors.Vocab at 0x7f6dd85434a8>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a3fd0>,
#  '我前': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577ba8>,
#  '凱恩': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfb00>,
#  '洗澡': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfb38>,
#  '跟場': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865390>,
#  '前面': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ae10>,
#  '活': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e47b8>,
#  '這就': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535860>,
#  '學生': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfb70>,
#  '在家': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfba8>,
#  'ε': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfbe0>,
#  '針': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ae48>,
#  '學長': <gensim.models.keyedvectors.Vocab at 0x7f6dd858ae80>,
#  '初心者': <gensim.models.keyedvectors.Vocab at 0x7f6dd88653c8>,
#  'し': <gensim.models.keyedvectors.Vocab at 0x7f6dd8540c50>,
#  '82217453': <gensim.models.keyedvectors.Vocab at 0x7f6dd882c550>,
#  '中文': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577be0>,
#  '蹦': <gensim.models.keyedvectors.Vocab at 0x7f6dd85434e0>,
#  '環錢': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a3908>,
#  '隱眼': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543518>,
#  '窩邊': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fb00>,
#  '第一名': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543550>,
#  '話題': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577c18>,
#  '隊': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535940>,
#  '這時間': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577c50>,
#  '謝謝': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fb38>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfc18>,
#  '就給': <gensim.models.keyedvectors.Vocab at 0x7f6dd859a668>,
#  '+++': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535908>,
#  '有代課': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfc50>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535898>,
#  '任': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535978>,
#  '在網': <gensim.models.keyedvectors.Vocab at 0x7f6dd858aeb8>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x7f6dd88654a8>,
#  '一切': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfc88>,
#  'ｧ': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fb70>,
#  '沒車': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e47f0>,
#  '屬': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fba8>,
#  '😨': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fbe0>,
#  '薰': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535b00>,
#  '基隆': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865518>,
#  '單挑': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfcc0>,
#  '不一樣': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4828>,
#  '林': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577cc0>,
#  '鳥': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535a20>,
#  '聰明': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535a58>,
#  '努力': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577cf8>,
#  '我場': <gensim.models.keyedvectors.Vocab at 0x7f6dd858af28>,
#  '居然': <gensim.models.keyedvectors.Vocab at 0x7f6dd854fb38>,
#  '很少': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1e48>,
#  '看人': <gensim.models.keyedvectors.Vocab at 0x7f6dd858af60>,
#  '........': <gensim.models.keyedvectors.Vocab at 0x7f6dd85435f8>,
#  '常用': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543630>,
#  '😜': <gensim.models.keyedvectors.Vocab at 0x7f6dd88655c0>,
#  '沒': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d588>,
#  '龍蝦': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c390>,
#  '看個': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4860>,
#  '呵': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577d30>,
#  '猜猜': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c400>,
#  '別': <gensim.models.keyedvectors.Vocab at 0x7f6dd858af98>,
#  '費': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4898>,
#  '真場': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865630>,
#  '1240085519356211': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fc18>,
#  '行動': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fc50>,
#  '≧': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535e10>,
#  '同時': <gensim.models.keyedvectors.Vocab at 0x7f6dd85436a0>,
#  '絲襪': <gensim.models.keyedvectors.Vocab at 0x7f6dd859f7b8>,
#  '扯': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfcf8>,
#  '台科': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577d68>,
#  '分數': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865668>,
#  '癢': <gensim.models.keyedvectors.Vocab at 0x7f6dd858afd0>,
#  '嚇到': <gensim.models.keyedvectors.Vocab at 0x7f6dd85436d8>,
#  'KWQc': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fcc0>,
#  '粉': <gensim.models.keyedvectors.Vocab at 0x7f6dd85359b0>,
#  '朋友': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a3940>,
#  '擠': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfd30>,
#  '電影': <gensim.models.keyedvectors.Vocab at 0x7f6dd85879e8>,
#  'cos': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543710>,
#  '最棒': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fcf8>,
#  'xD': <gensim.models.keyedvectors.Vocab at 0x7f6dd858cf98>,
#  '拷貝狗': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c048>,
#  'LINE': <gensim.models.keyedvectors.Vocab at 0x7f6dd85484e0>,
#  '志願': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfda0>,
#  '可愛': <gensim.models.keyedvectors.Vocab at 0x7f6dd8548278>,
#  '封鎖': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543668>,
#  '有用': <gensim.models.keyedvectors.Vocab at 0x7f6dd85712e8>,
#  '待': <gensim.models.keyedvectors.Vocab at 0x7f6dd88656d8>,
#  '土城': <gensim.models.keyedvectors.Vocab at 0x7f6dd85359e8>,
#  '→': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865710>,
#  'php': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543780>,
#  '噢': <gensim.models.keyedvectors.Vocab at 0x7f6dd8537128>,
#  '😔': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfdd8>,
#  '最討厭': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c0b8>,
#  '大一': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535b38>,
#  '問一個': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfe10>,
#  '戴': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c0f0>,
#  '有事': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c128>,
#  'aac': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e48d0>,
#  '還會': <gensim.models.keyedvectors.Vocab at 0x7f6dd85a7828>,
#  '陣頭': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c160>,
#  '魔法': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865550>,
#  '經過': <gensim.models.keyedvectors.Vocab at 0x7f6dd85437b8>,
#  'ড': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a39b0>,
#  '好像': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4908>,
#  '技術': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c1d0>,
#  'faijai': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c208>,
#  '搜': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c240>,
#  '像': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4978>,
#  '更好': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c278>,
#  'て': <gensim.models.keyedvectors.Vocab at 0x7f6dd853ae48>,
#  '玩弄': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fd30>,
#  '鄉下': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535c88>,
#  '早餐': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fd68>,
#  '學弟': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577da0>,
#  '再聊': <gensim.models.keyedvectors.Vocab at 0x7f6dd8537518>,
#  '唐': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e49b0>,
#  'え': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c2b0>,
#  'Share': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1630>,
#  '沒辦法': <gensim.models.keyedvectors.Vocab at 0x7f6dd853d940>,
#  '我勝利': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fdd8>,
#  '++': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e49e8>,
#  '附近': <gensim.models.keyedvectors.Vocab at 0x7f6dd8865b38>,
#  '懶': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c2e8>,
#  'cdn': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4a20>,
#  '超多': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543860>,
#  'ASD': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535cf8>,
#  '成為': <gensim.models.keyedvectors.Vocab at 0x7f6dd8594e10>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fe48>,
#  '死肥宅': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577dd8>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f6dd8543898>,
#  '吃屎': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577e10>,
#  '0088': <gensim.models.keyedvectors.Vocab at 0x7f6dd8535d30>,
#  '女子': <gensim.models.keyedvectors.Vocab at 0x7f6dd858c358>,
#  '81000': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4a58>,
#  '霸粉': <gensim.models.keyedvectors.Vocab at 0x7f6dd88a1cc0>,
#  '推廣': <gensim.models.keyedvectors.Vocab at 0x7f6dd85cfeb8>,
#  '單戀': <gensim.models.keyedvectors.Vocab at 0x7f6dd85438d0>,
#  'zz': <gensim.models.keyedvectors.Vocab at 0x7f6dd858f2b0>,
#  '您好': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4a90>,
#  '回頭': <gensim.models.keyedvectors.Vocab at 0x7f6dd859fef0>,
#  '我哥': <gensim.models.keyedvectors.Vocab at 0x7f6dd8594e48>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x7f6dd859d630>,
#  '孩子': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4ac8>,
#  '大概': <gensim.models.keyedvectors.Vocab at 0x7f6dd859ff28>,
#  'gif': <gensim.models.keyedvectors.Vocab at 0x7f6dd8577e80>,
#  '՞': <gensim.models.keyedvectors.Vocab at 0x7f6dd85e4b00>,
#  ...}

# %% [markdown]
# ## pick user top 10 word ( frequency-based )

# %%
top10_vector = np.zeros(shape=(l,10))
# top10_vector

# %%
import operator
for i in range(l):
    og_dict = dict()
#     print('\n user'+str(i+1))
#     if (len(test.iloc[i][1]))<10:
#         continue
    for j in range(len(grouped_data.iloc[i][1])):
        seglist = jieba.cut((grouped_data.iloc[i][1])[j])
        for word in seglist:
            if word not in stopwordset:
                if not word in og_dict.keys():
                    if word == " ":
                        continue
                    og_dict[word] = 1
                else:
                    og_dict[word] = int(og_dict[word]) + 1
    a = sorted(og_dict.items(), key=operator.itemgetter(1),reverse=True)
#     print(a)
    
    row = np.zeros(shape=(1,10))
    
    if len(a) >= 10:
        for x in range(10):
            if a[x][0] in model:
                show = float(model[a[x][0]])
#                 print(show)
                row[0][x] = show
    else:
        for x in range(len(a)):
#             print(a[x]) 
            if a[x][0] in model:
                show = float(model[a[x][0]])
#                 print(show)
                row[0][x] = show
#     print(row)
    top10_vector[i] = row

# %%
top10_vector.shape
# Out:
# (1019, 10)

# %%
# top10_vector

# %% [markdown]
# ## 分群

# %%
from sklearn import cluster, datasets

# KMeans 演算法
kmeans_fit = cluster.KMeans(n_clusters = 3,random_state=1170).fit(top10_vector)

# 印出分群結果
cluster_labels = kmeans_fit.labels_
print("分群結果 前10：")
print(cluster_labels[:10])
print("---")
# Out:
# 分群結果 前10：
# [2 0 0 0 0 0 0 0 0 1]
# ---

# %% [markdown]
# ## 分群結果數量

# %%
unique, counts = np.unique(cluster_labels, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 595, 1: 110, 2: 314}
